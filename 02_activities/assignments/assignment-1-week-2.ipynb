# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images
response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open(image_file)
x=np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y2=np.array([170,100,90,120,50])

# %%
fix, ax=plt.subplots(figsize=(7,3))
ax.plot(x,y2,color= "red")

ax_image = fix.add_axes([0.1,
0.11, 
0.15, 
0.35])

ax_image.imshow(image)
ax_image.axis('off')
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid')


sns.lineplot(data=tips, # choose our dataset
x='total_bill'
, # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data=tips,
x='total_bill'
,
y='tip')
tipgraph.set(title='Tips vs. Total Bill'
,
xlabel='Total Bill ($)'
,
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.lineplot(data=tips,
x='total_bill'
,
y='tip'
,
color = 'hotpink'
,
linestyle = '--'
,
linewidth = 3,
marker = 'o'
,
markerfacecolor = 'indigo')

tipgraph.set(title='Tips vs. Total Bill'
,
xlabel='Total Bill ($)'
,
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill'
,
y='tip'
, style = 'time'
, hue =
'day'
, palette = ['purple'
,
'hotpink'
,
'deepskyblue'
,
'yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill'
,
xlabel='Total Bill ($)'
,
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(
data = tips,
hue = 'day')

# %%
# Create a relational plot using seaborn, stored in the variable `daysplot`
daysplot = sns.relplot(
    # Specify the dataset to use, `tips` in this case, which contains information about restaurant tips
    data=tips,
    # Set the x-axis to represent the total bill amount
    x="total_bill",
    # Set the y-axis to represent the tip amount
    y="tip",
    # Use different colors for the scatter plot points based on the sex of the person
    hue="sex",
    # Create a separate subplot for each unique value in the "day" column (i.e., different days of the week)
    col="day",
    # Specify the type of plot to create, in this case, a scatter plot
    kind="scatter",
    # Arrange the subplots in a grid with a maximum of 2 columns
    col_wrap=2
)

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.23.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from plotly) (24.0)
# Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#    ---------------------------------------- 0.0/17.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.3 MB 217.9 kB/s eta 0:01:20
#    ---------------------------------------- 0.0/17.3 MB 330.3 kB/s eta 0:00:53
#    ---------------------------------------- 0.1/17.3 MB 512.0 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/17.3 MB 711.9 kB/s eta 0:00:25
#    ---------------------------------------- 0.2/17.3 MB 700.2 kB/s eta 0:00:25
#     --------------------------------------- 0.2/17.3 MB 765.3 kB/s eta 0:00:23
#     --------------------------------------- 0.3/17.3 MB 865.8 kB/s eta 0:00:20
#     --------------------------------------- 0.4/17.3 MB 1.0 MB/s eta 0:00:17
#    - -------------------------------------- 0.5
MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 9.5/17.3 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.6/17.3 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.7/17.3 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.8/17.3 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.9/17.3 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.9/17.3 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 10.1/17.3 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 10.2/17.3 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 10.2/17.3 MB 2.0 MB/s eta 0:00:04
#    ------------------------ --------------- 10.4/17.3 MB 2.1 MB/s eta 0:00:04
#    ------------------------ --------------- 10.6/17.3 MB 2.1 MB/s eta 0:00:04
#    ------------------------ --------------- 10.8/17.3 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 10.9/17.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 11.0/17.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 11.2/17.3 MB 2.2 MB/s eta 0:00:03
#    -------------------------- ------------- 11.3/17.3 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 11.6/17.3 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 11.7/17.3 MB 2.3 MB/s eta 0:00:03
#    --------------------------- ------------ 11.8/17.3 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 11.9/17.3 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 12.1/17.3 MB 2.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 12.2/17.3 MB 2.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 12.4/17.3 MB 2.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 12.5/17.3 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.7/17.3 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.9/17.3 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 13.1/17.3 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 13.3/17.3 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 13.3/17.3 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 13.5/17.3 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 13.6/17.3 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 13.8/17.3 MB 2.6 MB/s eta 0:00:02
#    -------------------------------- ------- 14.0/17.3 MB 2.6 MB/s eta 0:00:02
#    -------------------------------- ------- 14.2/17.3 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 14.3/17.3 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 14.5/17.3 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 14.6/17.3 MB 2.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 14.8/17.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.0/17.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.1/17.3 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.2/17.3 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.4/17.3 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.6/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 15.7/17.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 15.8/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 15.9/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 16.0/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 16.1/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 16.2/17.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 16.3/17.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 16.5/17.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 16.7/17.3 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 16.8/17.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  17.0/17.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  17.2/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 17.3/17.3 MB 2.6 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.23.0 tenacity-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go 
x1 = np.array(["Luffy"
,
"Zoro"
,
"Nami"
,
"Usopp"
,
"Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
# !pip install nbformat --upgrade
# Out:
# Requirement already satisfied: nbformat in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jsonschema>=2.6->nbformat) (0.19.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.1)
# Requirement already satisfied: pywin32>=300 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (306)

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))
graph.update_layout(
title="Pirate Scores"
,
xaxis_title="Pirates"
,
yaxis_title="Score")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'type': 'bar',
#               'x': array(['Luffy', 'Zoro', 'Nami', 'Usopp', 'Sanji'], dtype=object),
#               'y': array([110, 180, 240,  99, 220])}],
#     'layout': {'template': '...',
#                'title': {'text': 'Pirate Scores'},
#                'xaxis': {'title': {'text': 'Pirates'}},
#                'yaxis': {'title': {'text': 'Score'}}}
# })

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers'
, # we want points for a scatter plot
marker=dict(
size=15, # point size
color='hotpink'
, # point colour
opacity=1, # point transparency/alpha
line=dict(width=5, color='purple') # point outline
)))
graph.update_layout(
title='Interactive Pirate Plot'
,
xaxis_title='Pirates'
,
yaxis_title='Scores'
,
width=500, height=500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\User\miniconda3\envs\dsi_participant\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'marker': {'color': 'hotpink', 'line': {'color': 'purple', 'width': 5}, 'opacity': 1, 'size': 15},
#               'mode': 'markers',
#               'type': 'scatter',
#               'x': array(['Luffy', 'Zoro', 'Nami', 'Usopp', 'Sanji'], dtype=object),
#               'y': array([110, 180, 240,  99, 220])}],
#     'layout': {'height': 500,
#                'template': '...',
#                'title': {'text': 'Interactive Pirate Plot'},
#                'width': 500,
#                'xaxis': {'title': {'text': 'Pirates'}},
#                'yaxis': {'title': {'text': 'Scores'}}}
# })

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/300.6 kB 165.2 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/300.6 kB 217.9 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/300.6 kB 217.9 kB/s eta 0:00:02
#    ----------- --------------------------- 92.2/300.6 kB 374.1 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/300.6 kB 400.9 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.6 kB 525.1 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/300.6 kB 627.5 kB/s eta 0:00:01
#    -------------------------------------  297.0/300.6 kB 706.2 kB/s eta 0:00:01
#    -------------------------------------  297.0/300.6 kB 706.2 kB/s eta 0:00:01
#    -------------------------------------- 300.6/300.6 kB 562.7 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)
# generate our wordcloud image
wordcloud = WordCloud(background_color="white",
colormap = 'inferno').generate(text)
# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
plt.show()

# %%
# !pip install matplotlib-venn
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.3 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.3 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/40.3 kB 145.2 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.3 kB 145.2 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.3 kB 145.2 kB/s eta 0:00:01
#      -------------------------------------- 40.3/40.3 kB 112.9 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.9.0)
# Requirement already satisfied: numpy in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.24.4)
# Requirement already satisfied: scipy in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45335 sha256=9fe8eafb7b49f1b86439546639c35464ccb148f7cb7108339d7f65c89d43f1a5
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\5c\4b\48\d68a6531b1e1e7411520ab9f395994eb1ee2ffafd6837b7f6c
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.1

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
import matplotlib.pyplot as plt

# Define the sets
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

# Create an unweighted Venn diagram
diagram = venn2_unweighted([A, B], 
                           set_labels=('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5)

# Set the labels for the diagram
diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))

# Display the plot
plt.show()
